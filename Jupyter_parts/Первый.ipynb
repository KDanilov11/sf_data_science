# %%
2 + 2
# Out:
# 4

# %% [markdown]
# # First level heading
# ## Second level heading
#
# List:
#
# - List's first element
# - List's second element

# %% [markdown]
# ![изображение.png](attachment:4c66e51d-c474-40f0-90f3-db48e6224c76.png)
