# %% [markdown]
# string = 'Вы - самый крутой студент в SkillFactory'
# for letter in string:
#     print(letter, end = '')

# %%
string = 'Вы - самый крутой студент в SkillFactory'
for letter in string:
    print(letter, end = '_')
# Out:
# В_ы_ _-_ _с_а_м_ы_й_ _к_р_у_т_о_й_ _с_т_у_д_е_н_т_ _в_ _S_k_i_l_l_F_a_c_t_o_r_y_

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
print(proverb[0:11])
# Out:
# Программисты

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
print(proverb[-13:-9])
# Out:
# кофе

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
#proverb.split(',')[3][:-2]+'о'
print(proverb.split()[3][:-2]+'о')

# сплит делит на отдельные слова

# [:-2] исключает "а," из "устройства,"
#
# Out:
# устройство

# %% [markdown]
# # 3.2 Индексы и срезы

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
new_proverb =''
type(new_proverb)
odd = proverb[0::2]
even = proverb[1::2]
odd_index = 0
for letter in even:
    new_proverb = new_proverb + letter + odd[odd_index]
    odd_index+=1

    


# odd = proverb[0::2]
# even = proverb[1::2]


print(new_proverb)
# Out:
# Пормит  т срйта рорзюи оенвкд
# ргамсы-эоутосв,пебаущекфи  о.
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д

# %%
basic_word = 'программирование'

total = len(basic_word)
first = total+1
last = total-1

inverted_word = basic_word[last:-first:-1]


if basic_word == inverted_word:
    print('Слово "'+(basic_word)+'" является палиндромом')
else:
    print('Слово "'+(basic_word)+'" - это не палиндром')

#print(inverted_word)
#print(inverted_word)
# Out:
# Слово "щадащ" является палиндромом

# %% [markdown]
# # 3.3 Поиск подстроки в строке

# %%
city_list = ['Москва', 'Санкт-Петербург', 'Новосибирск', 
             'Екатеринбург', 'Нижний Новгород', 'Казань', 
             'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону']
counter = 0
for city in city_list:
    if ' ' in city or '-' in city:
        counter +=1
print('Число городов со сложными названиями - {}'.format(counter))
# Out:
# Число городов со сложными названиями - 3
# Число городов со сложными названиями - 10

# %%
counter = 0
for city in city_list:
    if ' ' in city or '-' in city:
        counter += 1
print('Число городов со сложными названиями - {}'.format(counter))

# %%
email = 'VeryBigBoss@skillfactory.ru'
pos = email.find('@')
domain = email[pos+1:]
print(domain)
# Out:
# skillfactory.ru

# %%
tongue_twister = 'Ехал Грека через реку, видит Грека - в реке рак. Сунул Грека руку в реку, рак за руку Греку - цап!'
counter = tongue_twister.count("Грек")
print(counter)
# Out:
# 4

# %%
counter = tongue_twister.count('Грек')
print(counter)

# %%
proverbs = ['Без труда не вытянешь и рыбку из пруда', 
            'Терпение и труд всё перетрут', 
            'Работа не волк - в лес не убежит', 
            'Чем труднее дело, тем выше честь', 
            'Учиться, учиться и учиться!']

counter = 0
for proverb in proverbs:
    if 'труд' in proverb:
        counter += 1

# %%
proverb = 'Хорошо написанная программа - это программа, написанная 2 раза'

while True:
    index = proverb.find('программа')
    if index == -1:
        break
    secret = proverb[:index].split()[-1]
    proverb = proverb[index+9:] 
    
print(secret)

# %%
number = 56.257

num_string = str(number)

# print(num_string[0:3])
#while True:
summ=0
coma = num_string.find('.')
decimal = num_string[coma+1:]
for digit in decimal:
    summ += int(digit)

print(summ)
# Out:
# 14

# %%
email = 'VeryBigBoss@skillfactory.ru'
pos = email.find('@')
domain = email[pos+1:]

# %%
email = 'VeryBigBoss@skillfactory.ru'
email[email.find('@')+1:]
# Out:
# 'skillfactory.ru'

# %% [markdown]
# # Задание 5**
#
# Дан список emails_list, содержащий электронные адреса десяти человек. Вам нужно написать программу, которая создаёт словарь emails_dict .Ключами словаря должны быть адреса доменов, а значениями — количество электронных адресов из списка emails_list, зарегистрированных на каждом домене.

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']



domens = []
dictos = {}
for adress in emails_list:
    domens.append(adress[adress.find('@')+1:])

print(domens)

import collections
c = collections.Counter()
for domen in domens:
    c[domen] +=1

print(c)

for domen in c:
    print(domen)

# print('dictos')
# print(dictos)
# Out:
# ['mail.ru', 'yandex.ru', 'yandex.ru', 'gmail.com', 'mail.ru', 'gmail.com', 'mail.ru', 'yandex.ru', 'yandex.ru', 'yandex.ru']
# Counter({'yandex.ru': 5, 'mail.ru': 3, 'gmail.com': 2})
# mail.ru
# yandex.ru
# gmail.com

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']

emails_dict ={}

for adress in emails_list:
    domain = adress[adress.find('@')+1:]
    if domain in emails_dict:
        emails_dict[domain]+=1
    else:
        emails_dict[domain] = 1
        
print(emails_dict)
# Out:
# {'mail.ru': 3, 'yandex.ru': 5, 'gmail.com': 2}

# %%
draw_dict = {
	'Россия': 'A',
	'Португалия': 'B',
	'Франция': 'C',
	'Дания': 'C',
	'Египет': 'A'
}
draw_new = {}
for country in draw_dict:
    if draw_dict[country] == 'A':
        draw_new[country]='A'

print(draw_new)
# Out:
# {'Россия': 'A', 'Египет': 'A'}

# %% [markdown]
# # 3.4 Преобразование строк

# %%
new_numbers = []
for number in '3,14 2,71 6,02 11,22 123,987'.split():
    new_numbers.append(float(number.replace(',', '.')))
print(new_numbers)
# Out:
# [3.14, 2.71, 6.02, 11.22, 123.987]

# %%
string = 'Интернет-открытки - это лучшее средство для мужчины сказать женщине о своих чувствах прямо в глаза.'
secret = string[24:30]

new_string = string.replace(secret.lower(), secret.upper()) 
print(secret)
print(new_string)
# Out:
# лучшее
# Интернет-открытки - это ЛУЧШЕЕ средство для мужчины сказать женщине о своих чувствах прямо в глаза.

# %% [markdown]
# ## Задание 4

# %%
string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.'

for letter in string:
    if letter in ('.', ',', ':', '-', '!', '?'):
        string = string.replace(letter, ':)')
print(string)
# Out:
# Тяжёлая интернет:)зависимость :) это когда ты выходишь из интернета:) а он из тебя нет:)

# %% [markdown]
# # Задание 5*
#
# Дана переменная name, в которой хранится имя пользователя, записанное русскими буквами. Напишите программу, которая перебирает имя по буквам и для каждой буквы выводит сообщение: "... - гласная буква" или "... - согласная буква", где вместо многоточия нужно подставить букву из имени пользователя.
#
# Значение переменной name не должно меняться в ходе выполнения программы. В сообщениях, выводимых на экран, буквы из имени пользователя должны выводиться в том же регистре, в котором они присутствуют в переменной name.

# %%
name = 'Севастиан'

vowels  = ['а', 'о', 'у', 'ы', 'э', 'я', 'ё', 'ю', 'и', 'е']
for letter in name:
    if letter.lower() in vowels:
        print(letter, '- гласная буква')
    else:
        print(letter, '- согласная буква')
# Out:
# С - согласная буква
# е - гласная буква
# в - согласная буква
# а - гласная буква
# с - согласная буква
# т - согласная буква
# и - гласная буква
# а - гласная буква
# н - согласная буква

# %% [markdown]
# # 3.5 Синтаксис регулярных выражений
# # 3.6 Модуль re

# %%
import re
# импортируем модёль ре
pattern = re.compile('[А-Я][а-я]*\W')
#задаём (компилируем) шаблон pattern

string = '!!! Йо! Учиться, учиться и учиться! Вперёд! Только вперёд!' 
 

#pattern.match(string)

#pattern.search(string)
pattern.findall(string)
#исполбзуем разные методы на на нашем шаблоне используя фразу как параметр
# Out:
# ['Йо!', 'Учиться,', 'Только ']

# %% [markdown]
# метод match не вернул нам ничего (точнее, вернул нам "Ничего", или None-значение), т.к. строка начинается с трёх восклицательных знаков, что не соответствует заданному шаблону;
#
# метод search нашёл только первое вхождение строки, совпавшей с шаблоном; данное вхождение соответствует подстроке "Йо!", и занимает позиции с 4 по 7;
#
# метод findall вернул список из трёх элементов, соответствующих заданной строке; кстати, обратите внимание, что слово "Вперёд" из-за присутствующей в нём буквы "ё" не было включено в список

# %%
import re
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

pattern = re.compile('\d+')
pattern.search(text)

pattern.findall(text)
# Out:
# ['1980', '1991', '1970']

# %%
import re
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

pattern = re.compile('[A-Za-z]+')
pattern.findall(text)
# Out:
# ['Python', 'CWI', 'Amoeba', 'Python', 'ABC', 'alt', 'sources']

# %%
[A-Za-z]+

# %% [markdown]
# Оператор 	Описание
# . 	Один любой символ, кроме новой строки \n.
# ? 	0 или 1 вхождение шаблона слева
# + 	1 и более вхождений шаблона слева
# * 	0 и более вхождений шаблона слева
# \w 	Любая цифра или буква (\W — все, кроме буквы или цифры)
# \d 	Любая цифра [0-9] (\D — все, кроме цифры)
# \s 	Любой пробельный символ (\S — любой непробельный символ)
# \b 	Граница слова
# [..] 	Один из символов в скобках ([^..] — любой символ, кроме тех, что в скобках)
# \ 	Экранирование специальных символов (\. означает точку или \+ — знак «плюс»)
# ^ и $ 	Начало и конец строки соответственно
# {n,m} 	От n до m вхождений ({,m} — от 0 до m)
# a|b 	Соответствует a или b
# () 	Группирует выражение и возвращает найденный текст
# \t, \n, \r 	Символ табуляции, новой строки и возврата каретки соответственно

# %%
import re
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

pattern = re.compile('[А-Яа-я]+ка')
pattern.findall(text)
# Out:
# ['Разработка', 'языка', 'языка', 'языка', 'языка', 'пресмыка']

# %%
import re
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

pattern = re.compile('[Аа][a-zа-яё][a-zа-яё][и]')
pattern.findall(text)
# Out:
# ['асши', 'амми', 'ающи', 'ающи']

# %%
import re
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

pattern = re.compile('[Аа][a-zа-яё][a-zа-яё][и]')
pattern.findall(text)
# Out:
# ['асши', 'амми', 'ающи', 'ающи']

# %%
import re
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'
pattern = re.compile('[АаОоУуИиыЕеЁёЭэЮюЯя][ ][БбВвГгДдЖжЗзЙйКкЛлМмНнПпРрСсТтФфХхЦцШшЩщ]')
pattern.findall(text)
# Out:
# ['а н',
#  'а в',
#  'о в',
#  'я р',
#  'я р',
#  'и Г',
#  'о н',
#  'а д',
#  'е н',
#  'и д',
#  'о н',
#  'е п',
#  'а Г',
#  'е н',
#  'а п',
#  'о в',
#  'е н',
#  'а п',
#  'о б',
#  'о к',
#  'о т',
#  'и П']

# %%
import re
pattern= re.compile('')
pattern.findall()

# %% [markdown]
# # 3.7 Построчное чтение файла

# %%
f = open('StudentsPerformance.csv')
for line in f:
        print(line)
f.close()
# Out:
# "gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"
#
# "female","group B","bachelor's degree","standard","none","72","72","74"
#
# "female","group C","some college","standard","completed","69","90","88"
#
# "female","group B","master's degree","standard","none","90","95","93"
#
# "male","group A","associate's degree","free/reduced","none","47","57","44"
#
# "male","group C","some college","standard","none","76","78","75"
#
# "female","group B","associate's degree","standard","none","71","83","78"
#
# "female","group B","some college","standard","completed","88","95","92"
#
# "male","group B","some college","free/reduced","none","40","43","39"
#
# "male","group D","high school","free/reduced","completed","64","64","67"
#
# "female","group B","high school","free/reduced","none","38","60","50"
#
# "male","group C","associate's degree","standard","none","58","54","52"
#
# ...

# %% [markdown]
# Считаем девочек и мальчиков
#
# Давайте попробуем ещё раз перебрать все строки файла, извлечь из них информацию про пол каждого из абитуриентов и посчитать соотношение мальчиков и девочек среди сдающих экзамен.
#
# Сначала опишем порядок наших действий:
#
#         Создаём две переменные-счётчики для подсчёта количества мальчиков и девочек.
#         Организуем цикл с параметром для построчного чтения файла. На каждом шаге цикла параметр будет принимать значение очередной строки.
#         Превращаем строку в список с помощью  метода split. В качестве разделителя указываем запятую.
#         Извлекаем из списка первый элемент и отрезаем от него первый и последний символы (кавычки).
#         Смотрим, чему равно значение извлечённого элемента. Если это «female», то увеличиваем на 1 счётчик девочек, если «male», — то счётчик мальчиков.
#         После завершения цикла выводим содержимое обоих счётчиков на экран.

# %%
f=open('StudentsPerformance.csv')
males = 0
females = 0
for line in f:
    info = line.split(',')
    gender = info[0][1:-1]
    if gender == 'female':
        females +=1
    elif gender == 'male':
        males +=1
print ('Мальчиков: {}, девочек: {}'.format(males, females))
# Out:
# Мадьчиков: 482, девочек: 518

# %%
f = open ('StudentsPerformance.csv')
bachelors = 0
for line in f:
    info = line.split(',')
    education = info[2][1:-1]
    if education == "bachelor's degree":
        bachelors +=1
print('Ботанов {}'.format(bachelors))
# Out:
# Ботанов 118

# %% [markdown]
# # Задание 2
# 1 point possible (graded)
#
# Сколько разных вариантов значений встречается в столбце "parental level of education"?
#
# Введите ответ в виде целого числа.
#
# Подсказка 1: для хранения уникальных вариантов вы можете использовать список.
#
# Подсказка 2: не забудьте, что первая строка файла содержит заголовки столбцов и не должна учитываться при обработке

# %%
f = open('StudentsPerformance.csv')
f.readline()  # пропуск первой строки
education_types = []
for line in f:    
    info = line.split(',')
    education = info[2][1:-1]
    if education not in education_types:
        education_types.append(education)

print(education_types)
print(len(education_types))
# Out:
# ["bachelor's degree", 'some college', "master's degree", "associate's degree", 'high school', 'some high school']
# 6

# %% [markdown]
# # Задание 3
# 1 point possible (graded)
#
# Сколько процентов абитуриентов полноценно пообедали перед экзаменом? Иными словами, у скольких процентов абитуриентов значение столбца "lunch" = "standard"?
#
# Ответ введите в виде десятичной дроби, в качестве разделителя используйте точку. Знак процента вводить не нужно.

# %%
f = open('StudentsPerformance.csv')
f.readline()
have_lunch = 0
total = 0

for line in f:
    info = line.split(',')
    lunch = info[3][1:-1]    
    if lunch == 'standard':
        have_lunch +=1
    total +=1
    
print(have_lunch/total)
# Out:
# 0.645

# %% [markdown]
# Сколько абитуриентов относится к этнической группе "group C"?
#
# Введите ответ в виде целого числа.

# %%
f = open('StudentsPerformance.csv')
f.readline()
group_C = 0

for line in f:
    info = line.split(',')
    group = info[1][1:-1]
    if group == 'group C':
        group_C +=1
print(group_C)
# Out:
# 319

# %% [markdown]
# # Сколько разных этнических групп встречается в файле?
#
# Введите ответ в виде целого числа.
#
# Подсказка 1: для хранения уникальных вариантов Вы можете использовать список.
#
# Подсказка 2: не забудьте, что первая строка файла содержит заголовки столбцов и не должна учитываться при обработке

# %%
f = open('StudentsPerformance.csv')
f.readline()
groups = []

for line in f:
    info = line.split(',')
    group = info[1][1:-1]
    if group not in groups:
        groups.append(group)

print(groups)
print(len(groups))
# Out:
# ['group B', 'group C', 'group A', 'group D', 'group E']
# 5

# %% [markdown]
# # 3.8 Преобразование файла в список
#
# ## Считаем оценки по математике
#
# Давайте начнём с простой задачи, цель которой — выгрузить из файла оценки, полученные абитуриентами на экзамене по математике, и сделать небольшой анализ полученных результатов.
#
# Давайте рассмотрим идею алгоритма, который поможет нам решить эту задачу:
#
#         Создаём пустой список math, в который будем добавлять оценки.
#         Открываем файл и начинаем перебирать его построчно в цикле с параметром.
#         Полученную на каждом шаге цикла строку превращаем во временный список. Проверяем, чему равен первый элемент списка, и если это «"gender"» — пропускаем шаг, поскольку такое значение первый элемент имеет только в строке с заголовками, а эту строку обрабатывать не надо.
#         Если обрабатываемая строка не заголовок, то извлекаем из неё элемент с индексом 5 (оценка по математике), отрезаем от него первый и последний символ (кавычки), переводим в тип int и добавляем к списку math.
#         После завершения цикла у нас будет список из 1000 элементов, содержащий оценки всех абитуриентов по математике.

# %%
math = []

f = open('StudentsPerformance.csv')
f.readline() # пропуск первой строки с названиями колонок

for line in f:
    info = line.split(',')
#     if info[0] == '"gender"':
#         continue
#     else:
#         mark = int(info[5][1:-1])
#         math.append(mark)        
      
    mark = int(info[5][1:-1])
    math.append(mark)
    
# print(math)
math_avg = sum(math)/len(math)
print(math_avg)

above_avg = 0

for mark in math:
    if mark > math_avg:
        above_avg +=1
        
print ('{} pupils have a mark above average'.format(above_avg))
print ('{}% of pupils have a mark above average'.format(above_avg/len(math)*100))
# Out:
# 66.089
# 493 pupils have a mark above average
# 49.3% of pupils have a mark above average

# %% [markdown]
# # Превращаем весь файл в систему вложенных списков
#
# Давайте попробуем превратить весь файл в список, состоящий из вложенных списков. Каждый вложенный список будет содержать одну строку с данными. При этом у текстовых данных будут удалены лишние кавычки, а числовые данные будут преобразованы в тип int. Для удобства выбора приёмов работы с текстовыми и числовыми данными мы воспользуемся модулем re и будем проверять каждый элемент строки на предмет того, содержит ли он цифры.
#
# Вот описание общей идеи алгоритма:
#
#         Создаём паттерн, описывающий строку, состоящую только из цифр.
#         Создаём пустой список (exams), в который будем помещать данные.
#         Открываем файл.
#         Начинаем построчный перебор содержимого файла с помощью цикла с параметром.
#         Преобразуем содержимое строки в список (info), и если первым элементом списка является значение «"gender"», пропускаем все остальные действия.
#         Создаём временный пустой список (new_line), в который мы будем помещать обработанные (лишённые кавычек и преобразованные в нужный формат) элементы строки.
#         Организуем вложенный цикл с параметром и последовательно перебираем в нём элементы строки info.
#         Проверяем, совпадает ли содержимое текущего элемента списка info с созданным нами паттерном (набор цифр).
#         Если текущий элемент строки содержит цифры (метод pattern.search(item) не возвращает значение  None) , извлекаем из обрабатываемого элемента строку, соответствующую паттерну (pattern.search(item)[0]), преобразуем ее в тип int и добавляем к списку new_line; иначе добавляем к списку new_line текущее значение параметра цикла без первого и последнего символов.
#         Добавляем список new_line к итоговому списку exams.

# %%
## EXAMPLE

import re

pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            if pattern.search(item) != None:
                new_line.append(int(pattern.search(item)[0]))
            else:
                new_line.append(item[1:-1])
        exams.append(new_line)
    print(new_line)
# Out:
# ['female', 'group B', "bachelor's degree", 'standard', 'none', 72, 72, 74]
# ['female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88]
# ['female', 'group B', "master's degree", 'standard', 'none', 90, 95, 93]
# ['male', 'group A', "associate's degree", 'free/reduced', 'none', 47, 57, 44]
# ['male', 'group C', 'some college', 'standard', 'none', 76, 78, 75]
# ['female', 'group B', "associate's degree", 'standard', 'none', 71, 83, 78]
# ['female', 'group B', 'some college', 'standard', 'completed', 88, 95, 92]
# ['male', 'group B', 'some college', 'free/reduced', 'none', 40, 43, 39]
# ['male', 'group D', 'high school', 'free/reduced', 'completed', 64, 64, 67]
# ['female', 'group B', 'high school', 'free/reduced', 'none', 38, 60, 50]
# ['male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52]
# ['male', 'group D', "associate's degree", 'standard', 'none', 40, 52, 43]
# ['female', 'group B', 'high school', 'standard', 'none', 65, 81, 73]
# ...

# %%
import re

pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')
f.readline()
for line in f:
    info = line.split(',')
#     if info[0] == '"gender"':
#         continue
#     else:
    new_line = []
    for item in info:
        if pattern.search(item) != None:
            new_line.append(int(pattern.search(item)[0]))
        else:
            new_line.append(item[1:-1])
        exams.append(new_line)
    print(new_line)
# Out:
# ['female', 'group B', "bachelor's degree", 'standard', 'none', 72, 72, 74]
# ['female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88]
# ['female', 'group B', "master's degree", 'standard', 'none', 90, 95, 93]
# ['male', 'group A', "associate's degree", 'free/reduced', 'none', 47, 57, 44]
# ['male', 'group C', 'some college', 'standard', 'none', 76, 78, 75]
# ['female', 'group B', "associate's degree", 'standard', 'none', 71, 83, 78]
# ['female', 'group B', 'some college', 'standard', 'completed', 88, 95, 92]
# ['male', 'group B', 'some college', 'free/reduced', 'none', 40, 43, 39]
# ['male', 'group D', 'high school', 'free/reduced', 'completed', 64, 64, 67]
# ['female', 'group B', 'high school', 'free/reduced', 'none', 38, 60, 50]
# ['male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52]
# ['male', 'group D', "associate's degree", 'standard', 'none', 40, 52, 43]
# ['female', 'group B', 'high school', 'standard', 'none', 65, 81, 73]
# ...

# %%
#Mine

import re

pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')
f.readline()
for line in f:
    info = line.split(',')
#     if info[0] == '"gender"':
#         continue
#     else:
    new_line = []
    for item in info:
        if pattern.search(item) != None:
            new_line.append(int(pattern.search(item)[0]))
        else:
            new_line.append(item[1:-1])
        exams.append(new_line)
    print(new_line)
# Out:
# ['female', 'group B', "bachelor's degree", 'standard', 'none', 72, 72, 74]
# ['female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88]
# ['female', 'group B', "master's degree", 'standard', 'none', 90, 95, 93]
# ['male', 'group A', "associate's degree", 'free/reduced', 'none', 47, 57, 44]
# ['male', 'group C', 'some college', 'standard', 'none', 76, 78, 75]
# ['female', 'group B', "associate's degree", 'standard', 'none', 71, 83, 78]
# ['female', 'group B', 'some college', 'standard', 'completed', 88, 95, 92]
# ['male', 'group B', 'some college', 'free/reduced', 'none', 40, 43, 39]
# ['male', 'group D', 'high school', 'free/reduced', 'completed', 64, 64, 67]
# ['female', 'group B', 'high school', 'free/reduced', 'none', 38, 60, 50]
# ['male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52]
# ['male', 'group D', "associate's degree", 'standard', 'none', 40, 52, 43]
# ['female', 'group B', 'high school', 'standard', 'none', 65, 81, 73]
# ...

# %%
"gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"
# Out:
# ('gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score')

# %% [markdown]
#  Задание 1
#
# Вычислите средний балл абитуриентов на экзамене по чтению (reading score).
#
# Введите ответ в виде одного числа. Не округляйте полученное значение.
#
# reading score is 6 (0 - 6)

# %%
import re

pattern re.compile ('\d+')

exams = []

# %%
import re

pattern = re.compile('\d+')

reading_score = []

f = open('StudentsPerformance.csv')
f.readline()
for line in f:
    info = line.split(',')

    new_line = []
    for item in info:
        if pattern.search(item) != None:
            new_line.append(int(pattern.search(item)[0]))
            
        else:
            new_line.append(item[1:-1])
        exams.append(new_line)
    print(new_line)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-3151af1f0530> in <module>
#      17         else:
#      18             new_line.append(item[1:-1])
# ---> 19         exams.append(new_line)
#      20     print(new_line)
#      21
#
# NameError: name 'exams' is not defined

# %%
math = []

f = open('StudentsPerformance.csv')
f.readline() # пропуск первой строки с названиями колонок

for line in f:
    info = line.split(',')

    mark = int(info[6][1:-1])
    math.append(mark)
    
# print(math)
math_avg = sum(math)/len(math)
print(math_avg)

below_avg = 0

for mark in math:
    if mark < math_avg:
        below_avg +=1
        
print ('{} pupils have a mark below average'.format(below_avg))
print ('{}% of pupils have a mark below average'.format(below_avg/len(math)*100))
# Out:
# 69.169
# 487 pupils have a mark below average
# 48.699999999999996% of pupils have a mark below average

# %% [markdown]
#  Задание 3
# 1 point possible (graded)
#
# Какой средний балл экзамена по чтению (reading score) получили девочки?
#
# Ответ округлите до трёх знаков после запятой.

# %%
reading_score = []
girls = 0

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    mark = int(info[6][1:-1])
    gender = str(info[0][1:-1])
    
    if gender == 'female':
        reading_score.append(mark)
        girls +=1
    
reading_g_avg = sum(reading_score)/len(reading_score)
print(reading_g_avg)
print(girls)
# Out:
# 72.60810810810811
# 518

# %% [markdown]
#  Задание 4
# 1 point possible (graded)
#
# Сколько абитуриентов получили на экзамене по письму (writing score) оценку выше 90?
#
# Введите количество абитуриентов в окно для ответа.

# %%
high = []

f=open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')

    mark = int(info[7][1:-2])
    if mark > 90:
        high.append(mark)
        

print(high)
print(len(high))
# Out:
# [93, 92, 92, 100, 98, 100, 92, 93, 93, 91, 100, 100, 94, 95, 93, 91, 94, 95, 95, 96, 100, 95, 95, 100, 93, 97, 100, 91, 91, 91, 92, 92, 94, 94, 97, 92, 100, 92, 96, 99, 91, 93, 99, 98, 100, 99, 99, 94, 92, 95, 92, 93, 93, 96, 91, 95, 91, 100, 91, 100, 91, 96, 100, 100, 100, 94, 91, 95]
# 68

# %% [markdown]
#  Задание 5
# 1 point possible (graded)
#
# Сколько процентов абитуриентов, получивших на экзамене по письму (writing score) оценку более 90, хорошо пообедали перед экзаменом (lunch = standard)?
#
# Введите ответ в виде дробного числа без знака процента, округлив до первого знака после запятой.

# %%
high_eat = []
high =[]

f=open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    mark = int(info[7][1:-2])
    lunch = str(info[3][1:-1])
    if mark > 90:
        high.append(mark)
        if lunch =='standard':
            high_eat.append(lunch)

print(len(high))
print(len(high_eat))
print((len(high_eat)/len(high))*100)
# Out:
# 68
# 59
# 86.76470588235294

# %% [markdown]
# # 3.9 Преобразование файла в словарь

# %% [markdown]
# Итак, начнём. Сначала мы выполним уже знакомые нам по предыдущему шагу действия:
#
#         Создадим пустой словарь (students), в котором будем накапливать данные.
#         Откроем файл для чтения из него данных.
#         Начнем построчно перебирать файл с помощью цикла с параметром.
#         Преобразуем очередную строку в список и смотрим, чему равен её первый элемент. Если элемент содержит заголовок первого столбца, то мы пропускаем последующие действия. Если обрабатываемая строка не заголовок, то мы извлекаем из неё данные об этнической группе, к которой принадлежит студент, и присваиваем эту информацию, отбросив лишние кавычки, переменной ethnicity:

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]

# %% [markdown]
# Далее мы переходим непосредственно к заполнению словаря. Заполнение словаря нам следует начать с проверки того, содержится ли уже в словаре ключ, совпадающий с названием этнической группы, хранящимся на данный момент в переменной ethnicity.
#
# Так как при обработке самых первых строк мы будем сталкиваться с ситуацией, когда соответствующий ключ в словаре отсутствует, давайте сначала напишем часть кода, которая будет выполняться именно в этом случае. Итак, если значение с нужным ключом в словаре отсутствует, нам нужно создать этот ключ и присвоить его значение единице, что будет означать, что пока мы нашли в файле только одного студента, относящегося к данной этнической группе:

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        if ethnicity in students:
            ...пока пропускаем этот шаг...
        else:
            students[ethnicity] = 1
# Out:
#   File "<ipython-input-33-3f4853e4ed46>", line 12
#     ...пока пропускаем этот шаг...
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Теперь нам осталось обработать последнее событие, т.е. описать действия, которые следует выполнять, если данный ключ уже есть в словаре.
#
# По факту, если ключ в словаре уже присутствует, это означает, что при переборе строк мы уже встречали информацию о студентах, относящихся к данной этнической группе, а при обработке текущей строки нашли информацию о ещё одном таком студенте.
#
# В этой ситуации нам нужно просто увеличить на единицу значение, которое уже хранится в словаре по данному ключу:

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        if ethnicity in students:
            students[ethnicity] += 1
        else:
            students[ethnicity] = 1

# %%
students = {}

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    ethnicity = info[1][1:-1]
    if ethnicity in students:
        students[ethnicity] +=1
    else:
        students[ethnicity] = 1
        
print(students)
# Out:
# {'group B': 190, 'group C': 319, 'group A': 89, 'group D': 262, 'group E': 140}

# %%
students = {}

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    gender = info[0][1:-1]
    if gender in students:
        students[gender] +=1
    else:
        students[gender] = 1
        
print(students)
# Out:
# {'female': 518, 'male': 482}

# %%
students ={}

f=open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    p_degree = info[2][1:-1]
    if p_degree in students:
        students[p_degree] += 1
    else:
        students[p_degree] = 1
        
print(students)
# Out:
# {"bachelor's degree": 118, 'some college': 226, "master's degree": 59, "associate's degree": 222, 'high school': 196, 'some high school': 179}

# %%
('gender',
 'race/ethnicity',
 'parental level of education',
 'lunch',
 'test preparation course',
 'math score',
 'reading score',
 'writing score')

# %% [markdown]
# Создаём вложенный словарь
#
# С помощью рассмотренной выше стратегии мы можем создавать словари и с более сложной структурой. Например, давайте рассмотрим код, который подсчитывает количество студентов, относящихся к разным этническим группам, а внутри каждой группы разделённых по уровню образования их родителей.
#
# Вот как выглядит часть словаря, содержащая сведения о группах В и С:

# %% [markdown]
# Как мы видим, структура словаря представляет собой следующее:
#
#         основной словарь содержит 5 ключей, соответствующих пяти этническим группам;
#         значением для каждого основного ключа является вложенный словарь, содержащий 6 ключей, соответствующих шести возможным уровням образования;
#         значения внутренних словарей — это данные о количестве студентов, относящихся к данной этнической группе и имеющих родителей с соответствующим уровнем образования.
#
# Давайте создадим такой словарь и снова, чтобы логика наших действий была максимально понятной, будем действовать постепенно и в той последовательности, в которой данные будут появляться в словаре.
#
# Сначала мы сделаем все необходимые приготовления и убедимся в том, что обрабатываемая нами строка — это не заголовки столбцов. Если мы обрабатываем строку с реальными данными, извлекаем из неё информацию об этнической группе студента (ethnicity) и уровне образования его родителей (parents).

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        parents = info[2][1:-1]

# %% [markdown]
# Теперь проверим, есть ли уже в словаре данные о текущей (содержащейся в обрабатываемой строке) этнической группе.
#
# Если таких данных нет (а при обработке первых строк это будет именно так), то нам надо будет сначала создать пустой словарь как значение, доступное в словаре students по ключу ethnicity. После этого в пустом словаре мы создаём ключ, соответствующий уровню образования родителей студента, чьи данные представлены в текущей строке файла (parents), и помещаем туда значение 1.
#
# Проводить проверку наличия ключа parents в словаре не имеет смысла, потому что сам словарь мы создали в предыдущей строке, и сейчас там нет никаких ключей:

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        parents = info[2][1:-1]
        if ethnicity in students:
           ...заполним позже...
        else:
            students[ethnicity] = {}
            students[ethnicity][parents] = 1
# Out:
#   File "<ipython-input-2-c90cdd686e38>", line 13
#     ...заполним позже...
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Теперь рассмотрим ситуацию, когда в словаре уже есть ключ, соответствующей данной этнической группе. В этом случае нам нужно проверить, содержится ли во вложенном словаре students[ethnicity] ключ, соответствующий уровню образования родителей студента, чьи данные обрабатываются в текущей строке. Если ключа пока нет, создаём его и помещаем в него значение, равное единице:

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        parents = info[2][1:-1]
        if ethnicity in students:
            if parents in students[ethnicity]:
                ...заполним позже...
            else:
                students[ethnicity][parents] = 1
        else:
            students[ethnicity] = {}
            students[ethnicity][parents] = 1

# %% [markdown]
# Если же ключ уже есть, увеличиваем на 1 значение, доступное по этому ключу на текущий момент:

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        parents = info[2][1:-1]
        if ethnicity in students:
            if parents in students[ethnicity]:
                students[ethnicity][parents] += 1
            else:
                students[ethnicity][parents] = 1
        else:
            students[ethnicity] = {}
            students[ethnicity][parents] = 1

# %%
students = {}

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    
    etnicity = info[1][1:-1]
    parents = info[2][1:-1]
    
    if etnicity in students: # есть ли уже ключ для данной etnicity в студентс?
        if parents in students[etnicity]:      #Есть ли уже в данной этнисити ключ парентс?
            students[etnicity][parents] +=1
        else:
            students[etnicity][parents]=1
    else:
        students[etnicity]={}            #create a new sub dictionary
        students[etnicity][parents]=1    #add current parents value as a key into sub dict, value is 1
        
print(students)
# Out:
# {'group B': {"bachelor's degree": 20, "master's degree": 6, "associate's degree": 41, 'some college': 37, 'high school': 48, 'some high school': 38}, 'group C': {'some college': 69, "associate's degree": 78, 'some high school': 49, 'high school': 64, "master's degree": 19, "bachelor's degree": 40}, 'group A': {"associate's degree": 14, 'some college': 18, "master's degree": 3, 'some high school': 24, "bachelor's degree": 12, 'high school': 18}, 'group D': {'high school': 44, "associate's degree": 50, 'some college': 67, "bachelor's degree": 28, "master's degree": 23, 'some high school': 50}, 'group E': {"master's degree": 8, 'some college': 35, "associate's degree": 39, "bachelor's degree": 18, 'some high school': 18, 'high school': 22}}

# %% [markdown]
#  Задание 1
# 1 point possible (graded)
#
# Сколько мальчиков хорошо пообедали перед экзаменом (lunch = standard)?
#
# Ответ введите в виде одного числа.
# нет ответа

# %%
students = {}
f= open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    
    gender = info[0][1:-1]
    lunch = info[3][1:-1]
    
    if gender in students:
        if lunch in students[gender]:
            students[gender][lunch] +=1
        else:
            students[gender][lunch] = 1
    else:
        students[gender] = {}
        students[gender][lunch]=1
        
print(students)
# Out:
# {'female': {'standard': 329, 'free/reduced': 189}, 'male': {'free/reduced': 166, 'standard': 316}}

# %% [markdown]
#  Задание 2
# 1 point possible (graded)
#
# Сколько мальчиков закончили подготовительные курсы (test preparation course = completed)?
#
# Ответ введите в виде одного числа.

# %%
students = {}

f=open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    gender = info[0][1:-1]
    course = info[4][1:-1]
    
    if gender in students:
        if course in students[gender]:
            students[gender][course]+=1
        else:
            students[gender][course]=1
    else:
        students[gender]= {}
        students[gender][course]=1

print(students)
# Out:
# {'female': {'none': 334, 'completed': 184}, 'male': {'none': 308, 'completed': 174}}

# %% [markdown]
#  Задание 3
# 1 point possible (graded)
#
# У скольких девочек родители имеют степень магистра (parental level of education = master's degree)?
#
# Ответ введите в виде одного числа.

# %%
students ={}

f=open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    gender = info[0][1:-1]
    parents = info[2][1:-1]
    if gender in students:
        if parents in students[gender]:
            students[gender][parents]+=1
        else:
            students[gender][parents]=1
    else:
        students[gender]={}
        students[gender][parents]=1

print(students)
# Out:
# {'female': {"bachelor's degree": 63, 'some college': 118, "master's degree": 36, "associate's degree": 116, 'high school': 94, 'some high school': 91}, 'male': {"associate's degree": 106, 'some college': 108, 'high school': 102, "master's degree": 23, "bachelor's degree": 55, 'some high school': 88}}

# %% [markdown]
#  Задание 4
# 1 point possible (graded)
#
# Сколько абитуриентов, относящихся к этнической группе С, закончили подготовительные курсы?
#
# Ответ введите в виде одного числа.

# %%
students = {}

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    race = info[1][1:-1]
    course = info[4][1:-1]
    if race in students:
        if course in students[race]:
            students[race][course]+=1
        else:
            students[race][course] =1
    else:
        students[race]= {}
        students[race][course]=1

print(students)
# Out:
# {'group B': {'none': 122, 'completed': 68}, 'group C': {'completed': 117, 'none': 202}, 'group A': {'none': 58, 'completed': 31}, 'group D': {'completed': 82, 'none': 180}, 'group E': {'none': 80, 'completed': 60}}

# %% [markdown]
#  Задание 5*
# 1 point possible (graded)
#
# Сколько девочек, родители которых имеют степень магистра, набрали по математике больше 90 баллов?
#
# Ответ введите в виде одного числа.

# %%
students = {}

f=open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    gender = str(info[0][1:-1])
    parents = str(info[2][1:-1])
    mark = int(info[5][1:-1])
    
    if mark >90:
        if gender in students:        
            if parents in students[gender]:            
                students[gender][parents]+=1
            else:            
                students[gender][parents] =1
        else:        
            students[gender]= {}
            students[gender][parents] = 1

print(students)
# Out:
# {'male': {'some college': 9, "associate's degree": 9, 'some high school': 3, "bachelor's degree": 5, "master's degree": 2, 'high school': 1}, 'female': {"bachelor's degree": 7, 'some high school': 2, 'high school': 1, 'some college': 2, "associate's degree": 7, "master's degree": 2}}

# %%
('gender',
 'race/ethnicity',
 'parental level of education',
 'lunch',
 'test preparation course',
 'math score',
 'reading score',
 'writing score')
# Out:
# ('gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score')

# %%
# Out:
# {'male': {'some college': 9, "associate's degree": 9, 'some high school': 3, "bachelor's degree": 5, "master's degree": 2, 'high school': 1}, 'female': {"bachelor's degree": 7, 'some high school': 2, 'high school': 1, 'some college': 2, "associate's degree": 7, "master's degree": 2}}

# %%
string = 'YAGAMI LITE'

print(string[-1:1])
print(string[-1::-1])
# Out:
# ETIL IMAGAY

# %%
'Hello' in 'Hello, Dolly!'.lower()
# Out:
# False

# %%
'your' in 'WhAt Is YoUr NaMe?'.lower()
# Out:
# True

# %%
'ARE'.lower() in 'how are you?'.upper()
# Out:
# False

# %%
'apples'.upper() in 'I like APPLES'.upper()
# Out:
# True

# %%
X='55,66'
X = float(X.replace(',', '.')) 
print(type(X))
# Out:
# <class 'float'>

# %%
X='55,66'
float(X.replace(',', '.')) 
print(type(X))
# Out:
# <class 'str'>

# %%
X='55,66'
X = int(X.replace(',', '.')) 
print(type(X))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-799259f49466> in <module>
#       1 X='55,66'
# ----> 2 X = int(X.replace(',', '.'))
#       3 print(type(X))
#
# ValueError: invalid literal for int() with base 10: '55.66'

# %%
X='55,66'
X = float(X.replace(',', '.')) 
print(type(X))
# Out:
# <class 'str'>

# %%
import re
pattern = re.compile('\d\d\d')
secret = pattern.findall('2 x 2 = 4') 

print(secret)
# Out:
# []

# %% [markdown]
# # 3.10 Итоговый тест

# %% [markdown]
# Задание 8
#
# 1 point possible (graded)
#
# Какой средний балл, полученный мальчиками на экзамене по чтению? Ответ округлите до трёх цифр после запятой.

# %%
reading_score = []
boys = 0

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    mark = int(info[6][1:-1])
    mat = int(info[5][1:-1])
    gender = str(info[0][1:-1])
    
#     if gender == 'female':
    if gender == 'male':      
            
        reading_score.append(mark)
        boys +=1
    
reading_g_avg = sum(reading_score)/len(reading_score)
print(reading_g_avg)
print(boys)
# Out:
# 65.47302904564316
# 482

# %% [markdown]
#  Задание 9
# 0/1 point (graded)
# Какой средний балл на экзамене по чтению набрали ученики, набравшие максимальный балл на экзамене по математике? Ответ округлите до трёх цифр после запятой.

# %%
reading_score = []
ppl = 0

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    mark = int(info[6][1:-1])
    mat = int(info[5][1:-1])
    gender = str(info[0][1:-1])
    
#     if gender == 'female':
    
    if mat == 100:
        print(info)
            
        reading_score.append(mark)
        ppl +=1
    
reading_g_avg = sum(reading_score)/len(reading_score)
print(reading_g_avg)
print(ppl)
# Out:
# ['"male"', '"group E"', '"associate\'s degree"', '"free/reduced"', '"completed"', '"100"', '"100"', '"93"\n']
# ['"female"', '"group E"', '"some college"', '"standard"', '"none"', '"100"', '"92"', '"97"\n']
# ['"female"', '"group E"', '"bachelor\'s degree"', '"standard"', '"none"', '"100"', '"100"', '"100"\n']
# ['"male"', '"group A"', '"some college"', '"standard"', '"completed"', '"100"', '"96"', '"86"\n']
# ['"male"', '"group D"', '"some college"', '"standard"', '"completed"', '"100"', '"97"', '"99"\n']
# ['"male"', '"group E"', '"bachelor\'s degree"', '"standard"', '"completed"', '"100"', '"100"', '"100"\n']
# ['"female"', '"group E"', '"associate\'s degree"', '"standard"', '"none"', '"100"', '"100"', '"100"\n']
# 97.85714285714286
# 7

# %% [markdown]
#  Задание 10
# 1 point possible (graded)
# Какой средний балл на экзамене по письму набрали ученики, которые плохо пообедали перед экзаменом (lunch = free/reduced)? Ответ округлите до двух цифр после запятой.

# %%
score = []
ppl = 0

f = open('StudentsPerformance.csv')
f.readline()

for line in f:
    info = line.split(',')
    mark = int(info[7][1:-2])
    #write = int(info[7][1:-2])
    lunch = str(info[3][1:-1])
    
#     if gender == 'female':
    
    if lunch == 'free/reduced':
#         print(info)
            
        score.append(mark)
        ppl +=1
    
w_g_avg = sum(score)/len(score)
print(w_g_avg)
print(ppl)
# Out:
# 63.02253521126761
# 355

# %%
('gender',
 'race/ethnicity',
 'parental level of education',
 'lunch',
 'test preparation course',
 'math score',
 'reading score',
 'writing score')
